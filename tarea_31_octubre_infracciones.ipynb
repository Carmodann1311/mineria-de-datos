# %% [markdown]
# <a href="https://colab.research.google.com/github/Carmodann1311/mineria-de-datos/blob/main/tarea_31_octubre_infracciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Cargar los datos, especificando la codificación 'latin-1'
df = pd.read_csv('/content/infracciones_infracciones_transito_2024_b1.csv', encoding='latin-1')

# %%
df.head()
# Out:
#    id_infraccion fecha_infraccion  ao_infraccion    mes  \
# 0  id-4228525321       01/01/2024           2024  Enero
# 1  id-4228525321       01/01/2024           2024  Enero
# 2  id-4228527042       02/01/2024           2024  Enero
# 3  id-4228527042       02/01/2024           2024  Enero
# 4  id-4228529695       02/01/2024           2024  Enero
#
#                                   categoria  articulo fraccion inciso  \
# 0          Estacionar en lugares prohíbidos        30        I  -----
# 1          Estacionar en lugares prohíbidos        30        I  -----
# 2  Incumplir con disposiciones de seguridad        37      III      D
# 3  Incumplir con disposiciones de seguridad        37      III      D
# 4          Estacionar en lugares prohíbidos        30        I  -----
#
#    parrafo    placa  ... marca_general   marca     submarca  \
# 0  TERCERO   765XVR  ...        NISSAN  NISSAN        TIIDA
# 1  TERCERO   765XVR  ...        NISSAN  NISSAN        TIIDA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132039 entries, 0 to 132038
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id_infraccion     132039 non-null  object
#  1   fecha_infraccion  132039 non-null  object
#  2   ao_infraccion     132039 non-null  int64
#  3   mes               132039 non-null  object
#  4   categoria         132036 non-null  object
#  5   articulo          132039 non-null  int64
#  6   fraccion          132039 non-null  object
#  7   inciso            132039 non-null  object
#  8   parrafo           131644 non-null  object
#  9   placa             131953 non-null  object
#  10  Color             33718 non-null   object
#  11  marca_general     71835 non-null   object
#  12  marca             119742 non-null  object
#  13  submarca          109276 non-null  object
#  14  en_la_calle       131630 non-null  object
#  15  entre_calle       131627 non-null  object
# ...

# %%
df.describe()
# Out:
#        ao_infraccion       articulo  longitud  latitud
# count       132039.0  132039.000000       0.0      0.0
# mean          2024.0      33.413052       NaN      NaN
# std              0.0       7.583844       NaN      NaN
# min           2024.0       7.000000       NaN      NaN
# 25%           2024.0      30.000000       NaN      NaN
# 50%           2024.0      33.000000       NaN      NaN
# 75%           2024.0      37.000000       NaN      NaN
# max           2024.0      50.000000       NaN      NaN

# %%
df.fillna(method='ffill', inplace=True)  # Example: forward fill
# Out:
# <ipython-input-32-ccac8d51870e>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)  # Example: forward fill

# %%
df['fecha_infraccion'] = pd.to_datetime(df['fecha_infraccion'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-2bad63b5c14a> in <cell line: 1>()
# ----> 1 df['fecha_infraccion'] = pd.to_datetime(df['fecha_infraccion'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061                 result = arg.tz_localize("utc")
#    1062     elif isinstance(arg, ABCSeries):
# -> 1063         cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064         if not cache_array.empty:
#    1065             result = arg.map(cache_array)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/tools/datetimes.py in _maybe_cache(arg, format, cache, convert_listlike)
#     245         unique_dates = unique(arg)
#     246         if len(unique_dates) < len(arg):
# ...

# %%
df['day_of_week'] = df['fecha_infraccion'].dt.dayofweek

# %%
df = pd.get_dummies(df, columns=['categoria', 'alcaldia'])

# %%
from sklearn.model_selection import train_test_split
    X = df[['feature1', 'feature2', ...]]  # Features
    y = df['target_variable']  # Target
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
    model = LogisticRegression()
    model.fit(X_train, y_train)

# %%
from sklearn.metrics import accuracy_score
    y_pred = model.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
